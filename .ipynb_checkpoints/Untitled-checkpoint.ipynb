# %%
import shutil

# %%
import os

# %%
import pandas as pd

# %%
original = "./Data/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/"

# %%
print(len(os.listdir(original)))
# Out:
# 20

# %%
df = pd.read_csv(os.path.join(original, "images_train.txt"))

# %%
df.head()
# Out:
#      Image
# 0  1025794
# 1  1340192
# 2    56978
# 3   698580
# 4   450014

# %%
images_path = os.path.join(original, "images")
images_path_train = os.path.join(original, "images_train.txt")

# %%
print(images_path)
print(images_path_train)
# Out:
# ./Data/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images
# ./Data/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images_train.txt

# %%
train_df = pd.read_csv(images_path_train)

# %%
train_list = train_df['Image'].values.tolist()

# %%
train_copy = []
count2 = 0
for train_image in train_list:
    for image in os.listdir(images_path):
        image_name = image.replace(".jpg","")
        if image_name == str(train_image):
            train_copy.append(os.path.join(images_path, image))
            break
    count2 += 1
    print(str(count2) + "/" + str(3334) )
    if count2 > 100:
        break
# Out:
# 1/3334
# 2/3334
# 3/3334
# 4/3334
# 5/3334
# 6/3334
# 7/3334
# 8/3334
# 9/3334
# 10/3334
# 11/3334
# 12/3334
# 13/3334
# 14/3334
# 15/3334
# 16/3334
# 17/3334
# 18/3334
# 19/3334
# 20/3334
# 21/3334
# 22/3334
# 23/3334
# 24/3334
# 25/3334
# 26/3334
# 27/3334
# 28/3334
# 29/3334
# 30/3334
# 31/3334
# 32/3334
# 33/3334
# 34/3334
# 35/3334
# 36/3334
# 37/3334
# 38/3334
# 39/3334
# 40/3334
# 41/3334
# 42/3334
# 43/3334
# 44/3334
# 45/3334
# 46/3334
# 47/3334
# 48/3334
# 49/3334
# 50/3334
# 51/3334
# 52/3334
# 53/3334
# 54/3334
# 55/3334
# 56/3334
# 57/3334
# 58/3334
# 59/3334
# 60/3334
# 61/3334
# 62/3334
# 63/3334
# 64/3334
# 65/3334
# 66/3334
# 67/3334
# 68/3334
# 69/3334
# 70/3334
# 71/3334
# 72/3334
# 73/3334
# 74/3334
# 75/3334
# 76/3334
# 77/3334
# 78/3334
# 79/3334
# 80/3334
# 81/3334
# 82/3334
# 83/3334
# 84/3334
# 85/3334
# 86/3334
# 87/3334
# 88/3334
# 89/3334
# 90/3334
# 91/3334
# 92/3334
# 93/3334
# 94/3334
# 95/3334
# 96/3334
# 97/3334
# 98/3334
# 99/3334
# 100/3334
# ...

# %%
old_paths = []
new_paths
count2 = 0
for train_image in train_list:
    image_name = str(train_image) + ".jpg"
    train_copy.append(os.path.join(images_path, image_name))
    count2 += 1
    print(str(count2) + "/" + str(3334) )
# Out:
# 1/3334
# 2/3334
# 3/3334
# 4/3334
# 5/3334
# 6/3334
# 7/3334
# 8/3334
# 9/3334
# 10/3334
# 11/3334
# 12/3334
# 13/3334
# 14/3334
# 15/3334
# 16/3334
# 17/3334
# 18/3334
# 19/3334
# 20/3334
# 21/3334
# 22/3334
# 23/3334
# 24/3334
# 25/3334
# 26/3334
# 27/3334
# 28/3334
# 29/3334
# 30/3334
# 31/3334
# 32/3334
# 33/3334
# 34/3334
# 35/3334
# 36/3334
# 37/3334
# 38/3334
# 39/3334
# 40/3334
# 41/3334
# 42/3334
# 43/3334
# 44/3334
# 45/3334
# 46/3334
# 47/3334
# 48/3334
# 49/3334
# 50/3334
# 51/3334
# 52/3334
# 53/3334
# 54/3334
# 55/3334
# 56/3334
# 57/3334
# 58/3334
# 59/3334
# 60/3334
# 61/3334
# 62/3334
# 63/3334
# 64/3334
# 65/3334
# 66/3334
# 67/3334
# 68/3334
# 69/3334
# 70/3334
# 71/3334
# 72/3334
# 73/3334
# 74/3334
# 75/3334
# 76/3334
# 77/3334
# 78/3334
# 79/3334
# 80/3334
# 81/3334
# 82/3334
# 83/3334
# 84/3334
# 85/3334
# 86/3334
# 87/3334
# 88/3334
# 89/3334
# 90/3334
# 91/3334
# 92/3334
# 93/3334
# 94/3334
# 95/3334
# 96/3334
# 97/3334
# 98/3334
# 99/3334
# 100/3334
# ...

# %%
from __future__ import print_function
import sys


train_dir = "./split_data/train"
DR = "./split_data/train"
if not os.path.exists(DR):
    os.mkdir(DR)

for filename, class_name in labels.values:
    # Create subdirectory with `class_name`
    if not os.path.exists(DR + str(class_name)):
        os.mkdir(DR + str(class_name))
    src_path = train_dir + '/'+ filename
    dst_path = DR + str(class_name) + '/' + filename
    try:
        shutil.move(src_path, dst_path)
        print("sucessful")
    except IOError as e:
        print('Unable to copy file {} to {}'
              .format(src_path, dst_path))
    except:
        print('When try copy file {} to {}, unexpected error: {}'
              .format(src_path, dst_path, sys.exc_info()))
# Out:
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...

# %%
classes = pd.read_csv("./Data/train.csv")

# %%
labels = classes.drop(columns=['Classes'])

# %%
src = "./Data/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images"
dst = "./split_data/train"
for image in train_names:
    dst_path = os.path.join(dst,image)
    src_path = os.path.join(dst,image)
    try:
        shutil.copy(src_path, dst_path)
        print("sucessful")
    except IOError as e:
        print('Unable to copy file {} to {}'
              .format(src_path, dst_path))
    except:
        print('When try copy file {} to {}, unexpected error: {}'
              .format(src_path, dst_path, sys.exc_info()))
# Out:
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...

# %%
train_names = labels['filename'].tolist()

# %%
labels["Labels"].nunique()
# Out:
# 100

# %%
labels
# Out:
#          filename  Labels
# 0     1025794.jpg       0
# 1     1340192.jpg       0
# 2     0056978.jpg       0
# 3     0698580.jpg       0
# 4     0450014.jpg       0
# ...           ...     ...
# 3329  1577680.jpg      99
# 3330  1826676.jpg      99
# 3331  0472681.jpg      99
# 3332  1597829.jpg      99
# 3333  0197891.jpg      99
#
# [3334 rows x 2 columns]

# %%
labels_test = pd.read_csv("./Data/test.csv").drop(columns = 'Classes')
labels_val =  pd.read_csv("./Data/val.csv").drop(columns='Classes')

# %% [markdown]
# ## Val

# %%
test_names = labels_test['filename'].tolist()
val_names = labels_val['filename'].tolist()

# %%
src = "./Data/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images"
dst = "./split_data/val"
for image in val_names:
    dst_path = os.path.join(dst,image)
    src_path = os.path.join(src,image)
    try:
        shutil.copy(src_path, dst_path)
        print("sucessful")
    except IOError as e:
        print('Unable to copy file {} to {}'
              .format(src_path, dst_path))
    except:
        print('When try copy file {} to {}, unexpected error: {}'
              .format(src_path, dst_path, sys.exc_info()))
# Out:
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...

# %%
from __future__ import print_function
import sys


train_dir = "./split_data/val"
DR = "./split_data/val"
if not os.path.exists(DR):
    os.mkdir(DR)

for filename, class_name in labels_val.values:
    # Create subdirectory with `class_name`
    if not os.path.exists(DR + str(class_name)):
        os.mkdir(DR + str(class_name))
    src_path = train_dir + '/'+ filename
    dst_path = DR + str(class_name) + '/' + filename
    try:
        shutil.move(src_path, dst_path)
        print("sucessful")
    except IOError as e:
        print('Unable to copy file {} to {}'
              .format(src_path, dst_path))
    except:
        print('When try copy file {} to {}, unexpected error: {}'
              .format(src_path, dst_path, sys.exc_info()))
# Out:
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...

# %%
src = "./Data/fgvc-aircraft-2013b/fgvc-aircraft-2013b/data/images"
dst = "./split_data/test"
for image in test_names:
    dst_path = os.path.join(dst,image)
    src_path = os.path.join(src,image)
    try:
        shutil.copy(src_path, dst_path)
        print("sucessful")
    except IOError as e:
        print('Unable to copy file {} to {}'
              .format(src_path, dst_path))
    except:
        print('When try copy file {} to {}, unexpected error: {}'
              .format(src_path, dst_path, sys.exc_info()))
# Out:
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...

# %%
train_dir = "./split_data/test"
DR = "./split_data/test"
if not os.path.exists(DR):
    os.mkdir(DR)

for filename, class_name in labels_test.values:
    # Create subdirectory with `class_name`
    if not os.path.exists(DR + str(class_name)):
        os.mkdir(DR + str(class_name))
    src_path = train_dir + '/'+ filename
    dst_path = DR + str(class_name) + '/' + filename
    try:
        shutil.move(src_path, dst_path)
        print("sucessful")
    except IOError as e:
        print('Unable to copy file {} to {}'
              .format(src_path, dst_path))
    except:
        print('When try copy file {} to {}, unexpected error: {}'
              .format(src_path, dst_path, sys.exc_info()))
# Out:
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-97-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install opencv-python

# %%
# !pip3 install opencv-python

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-101-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'
